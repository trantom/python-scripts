# %% [markdown]
# # Import libraries

# %%
import csv
import time
import requests

url = 'https://gbfs.bcycle.com/bcycle_lametro/station_information.json'
r = requests.get(url)

bikestation_data = r.json()
print(bikestation_data)
# Out:
# {'ttl': 60, 'data': {'Stations': [{'lon': -118.25854, 'lat': 34.0485, 'region_id': 'bcycle_lametro_region_1', 'address': '723 Flower Street', 'name': '7th & Flower', 'station_id': 'bcycle_lametro_3005'}, {'lon': -118.25667, 'lat': 34.04554, 'region_id': 'bcycle_lametro_region_1', 'address': '729 S Olive Street', 'name': 'Olive & 8th', 'station_id': 'bcycle_lametro_3006'}, {'lon': -118.25459, 'lat': 34.05048, 'region_id': 'bcycle_lametro_region_1', 'address': '557 S 5th Street', 'name': '5th & Grand', 'station_id': 'bcycle_lametro_3007'}, {'lon': -118.26273, 'lat': 34.04661, 'region_id': 'bcycle_lametro_region_1', 'address': '865 S Figueroa Street', 'name': 'Figueroa & 9th', 'station_id': 'bcycle_lametro_3008'}, {'lon': -118.25487, 'lat': 34.03705, 'region_id': 'bcycle_lametro_region_1', 'address': '401 East 11th Street', 'name': '11th & Maple', 'station_id': 'bcycle_lametro_3010'}, {'lon': -118.26798, 'lat': 34.04113, 'region_id': 'bcycle_lametro_region_1', 'address': '1259-1299 S Figueroa Street', 'name': 'Figueroa & Pico', 'station_id': 'bcycle_lametro_3011'}, {'lon': -118.26302, 'lat': 33.77982, 'region_id': 'bcycle_lametro_region_1', 'address': '128 W Anaheim St', 'name': 'Anaheim & Avalon', 'station_id': 'bcycle_lametro_3013'}, {'lon': -118.23721, 'lat': 34.05661, 'region_id': 'bcycle_lametro_region_1', 'address': '834 N Alameda St', 'name': 'Union Station West Portal', 'station_id': 'bcycle_lametro_3014'}, {'lon': -118.24156, 'lat': 34.0529, 'region_id': 'bcycle_lametro_region_1', 'address': '201 N Los Angeles Street', 'name': 'Los Angeles & Temple', 'station_id': 'bcycle_lametro_3016'}, {'lon': -118.26014, 'lat': 34.04373, 'region_id': 'bcycle_lametro_region_1', 'address': '919 S Grand Ave', 'name': 'Grand & Olympic', 'station_id': 'bcycle_lametro_3018'}, {'lon': -118.26086, 'lat': 34.03861, 'region_id': 'bcycle_lametro_region_1', 'address': '129 W 12th Street', 'name': '12th & Hill', 'station_id': 'bcycle_lametro_3019'}, {'lon': -118.26709, 'lat': 34.03105, 'region_id': 'bcycle_lametro_region_1', 'address': '1950 S Hill Street', 'name': 'Hill & Washington', 'station_id': 'bcycle_lametro_3020'}, {'lon': -118.23309, 'lat': 34.04607, 'region_id': 'bcycle_lametro_region_1', 'address': '999 E Third Street', 'name': '3rd & Santa Fe', 'station_id': 'bcycle_lametro_3022'}, {'lon': -118.24097, 'lat': 34.05091, 'region_id': 'bcycle_lametro_region_1', 'address': '134 Judge John Aiso Street', 'name': '1st & Judge John Aiso', 'station_id': 'bcycle_lametro_3023'}, {'lon': -118.24897, 'lat': 34.05772, 'region_id': 'bcycle_lametro_region_1', 'address': '111 N Hope Street', 'name': 'Hope & 1st', 'station_id': 'bcycle_lametro_3024'}, {'lon': -118.26808, 'lat': 34.03286, 'region_id': 'bcycle_lametro_region_1', 'address': '1014 S Grand Ave', 'name': 'Grand & Washington', 'station_id': 'bcycle_lametro_3025'}, {'lon': -118.24588, 'lat': 34.06318, 'region_id': 'bcycle_lametro_region_1', 'address': '668 N Figueroa Street', 'name': 'Figueroa & Cesar Chavez', 'station_id': 'bcycle_lametro_3026'}, {'lon': -118.24716, 'lat': 34.04998, 'region_id': 'bcycle_lametro_region_1', 'address': '300 S Spring Street', 'name': 'Spring & 3rd', 'station_id': 'bcycle_lametro_3027'}, {'lon': -118.24609, 'lat': 34.05832, 'region_id': 'bcycle_lametro_region_1', 'address': '310 N Grand Ave', 'name': 'Grand & Temple', 'station_id': 'bcycle_lametro_3028'}, {'lon': -118.24642, 'lat': 34.04885, 'region_id': 'bcycle_lametro_region_1', 'address': '334 S Main Street', 'name': 'Main & 4th', 'station_id': 'bcycle_lametro_3029'}, {'lon': -118.24353, 'lat': 34.05194, 'region_id': 'bcycle_lametro_region_1', 'address': '120 S Main Street', 'name': 'Main & 1st', 'station_id': 'bcycle_lametro_3030'}, {'lon': -118.25244, 'lat': 34.0447, 'region_id': 'bcycle_lametro_region_1', 'address': '201 W 7th Street', 'name': '7th & Spring', 'station_id': 'bcycle_lametro_3031'}, {'lon': -118.25588, 'lat': 34.04989, 'region_id': 'bcycle_lametro_region_1', 'address': '557 S Hope Street', 'name' ...

# %%
bikestation_data_dict = bikestation_data['data']
print(bikestation_data_dict)
# Out:
# {'Stations': [{'lon': -118.25854, 'lat': 34.0485, 'region_id': 'bcycle_lametro_region_1', 'address': '723 Flower Street', 'name': '7th & Flower', 'station_id': 'bcycle_lametro_3005'}, {'lon': -118.25667, 'lat': 34.04554, 'region_id': 'bcycle_lametro_region_1', 'address': '729 S Olive Street', 'name': 'Olive & 8th', 'station_id': 'bcycle_lametro_3006'}, {'lon': -118.25459, 'lat': 34.05048, 'region_id': 'bcycle_lametro_region_1', 'address': '557 S 5th Street', 'name': '5th & Grand', 'station_id': 'bcycle_lametro_3007'}, {'lon': -118.26273, 'lat': 34.04661, 'region_id': 'bcycle_lametro_region_1', 'address': '865 S Figueroa Street', 'name': 'Figueroa & 9th', 'station_id': 'bcycle_lametro_3008'}, {'lon': -118.25487, 'lat': 34.03705, 'region_id': 'bcycle_lametro_region_1', 'address': '401 East 11th Street', 'name': '11th & Maple', 'station_id': 'bcycle_lametro_3010'}, {'lon': -118.26798, 'lat': 34.04113, 'region_id': 'bcycle_lametro_region_1', 'address': '1259-1299 S Figueroa Street', 'name': 'Figueroa & Pico', 'station_id': 'bcycle_lametro_3011'}, {'lon': -118.26302, 'lat': 33.77982, 'region_id': 'bcycle_lametro_region_1', 'address': '128 W Anaheim St', 'name': 'Anaheim & Avalon', 'station_id': 'bcycle_lametro_3013'}, {'lon': -118.23721, 'lat': 34.05661, 'region_id': 'bcycle_lametro_region_1', 'address': '834 N Alameda St', 'name': 'Union Station West Portal', 'station_id': 'bcycle_lametro_3014'}, {'lon': -118.24156, 'lat': 34.0529, 'region_id': 'bcycle_lametro_region_1', 'address': '201 N Los Angeles Street', 'name': 'Los Angeles & Temple', 'station_id': 'bcycle_lametro_3016'}, {'lon': -118.26014, 'lat': 34.04373, 'region_id': 'bcycle_lametro_region_1', 'address': '919 S Grand Ave', 'name': 'Grand & Olympic', 'station_id': 'bcycle_lametro_3018'}, {'lon': -118.26086, 'lat': 34.03861, 'region_id': 'bcycle_lametro_region_1', 'address': '129 W 12th Street', 'name': '12th & Hill', 'station_id': 'bcycle_lametro_3019'}, {'lon': -118.26709, 'lat': 34.03105, 'region_id': 'bcycle_lametro_region_1', 'address': '1950 S Hill Street', 'name': 'Hill & Washington', 'station_id': 'bcycle_lametro_3020'}, {'lon': -118.23309, 'lat': 34.04607, 'region_id': 'bcycle_lametro_region_1', 'address': '999 E Third Street', 'name': '3rd & Santa Fe', 'station_id': 'bcycle_lametro_3022'}, {'lon': -118.24097, 'lat': 34.05091, 'region_id': 'bcycle_lametro_region_1', 'address': '134 Judge John Aiso Street', 'name': '1st & Judge John Aiso', 'station_id': 'bcycle_lametro_3023'}, {'lon': -118.24897, 'lat': 34.05772, 'region_id': 'bcycle_lametro_region_1', 'address': '111 N Hope Street', 'name': 'Hope & 1st', 'station_id': 'bcycle_lametro_3024'}, {'lon': -118.26808, 'lat': 34.03286, 'region_id': 'bcycle_lametro_region_1', 'address': '1014 S Grand Ave', 'name': 'Grand & Washington', 'station_id': 'bcycle_lametro_3025'}, {'lon': -118.24588, 'lat': 34.06318, 'region_id': 'bcycle_lametro_region_1', 'address': '668 N Figueroa Street', 'name': 'Figueroa & Cesar Chavez', 'station_id': 'bcycle_lametro_3026'}, {'lon': -118.24716, 'lat': 34.04998, 'region_id': 'bcycle_lametro_region_1', 'address': '300 S Spring Street', 'name': 'Spring & 3rd', 'station_id': 'bcycle_lametro_3027'}, {'lon': -118.24609, 'lat': 34.05832, 'region_id': 'bcycle_lametro_region_1', 'address': '310 N Grand Ave', 'name': 'Grand & Temple', 'station_id': 'bcycle_lametro_3028'}, {'lon': -118.24642, 'lat': 34.04885, 'region_id': 'bcycle_lametro_region_1', 'address': '334 S Main Street', 'name': 'Main & 4th', 'station_id': 'bcycle_lametro_3029'}, {'lon': -118.24353, 'lat': 34.05194, 'region_id': 'bcycle_lametro_region_1', 'address': '120 S Main Street', 'name': 'Main & 1st', 'station_id': 'bcycle_lametro_3030'}, {'lon': -118.25244, 'lat': 34.0447, 'region_id': 'bcycle_lametro_region_1', 'address': '201 W 7th Street', 'name': '7th & Spring', 'station_id': 'bcycle_lametro_3031'}, {'lon': -118.25588, 'lat': 34.04989, 'region_id': 'bcycle_lametro_region_1', 'address': '557 S Hope Street', 'name': 'Hope & 6th', 'sta ...

# %%
bikestation_data_list = bikestation_data_dict['Stations']
print(bikestation_data_list)
# Out:
# [{'lon': -118.25854, 'lat': 34.0485, 'region_id': 'bcycle_lametro_region_1', 'address': '723 Flower Street', 'name': '7th & Flower', 'station_id': 'bcycle_lametro_3005'}, {'lon': -118.25667, 'lat': 34.04554, 'region_id': 'bcycle_lametro_region_1', 'address': '729 S Olive Street', 'name': 'Olive & 8th', 'station_id': 'bcycle_lametro_3006'}, {'lon': -118.25459, 'lat': 34.05048, 'region_id': 'bcycle_lametro_region_1', 'address': '557 S 5th Street', 'name': '5th & Grand', 'station_id': 'bcycle_lametro_3007'}, {'lon': -118.26273, 'lat': 34.04661, 'region_id': 'bcycle_lametro_region_1', 'address': '865 S Figueroa Street', 'name': 'Figueroa & 9th', 'station_id': 'bcycle_lametro_3008'}, {'lon': -118.25487, 'lat': 34.03705, 'region_id': 'bcycle_lametro_region_1', 'address': '401 East 11th Street', 'name': '11th & Maple', 'station_id': 'bcycle_lametro_3010'}, {'lon': -118.26798, 'lat': 34.04113, 'region_id': 'bcycle_lametro_region_1', 'address': '1259-1299 S Figueroa Street', 'name': 'Figueroa & Pico', 'station_id': 'bcycle_lametro_3011'}, {'lon': -118.26302, 'lat': 33.77982, 'region_id': 'bcycle_lametro_region_1', 'address': '128 W Anaheim St', 'name': 'Anaheim & Avalon', 'station_id': 'bcycle_lametro_3013'}, {'lon': -118.23721, 'lat': 34.05661, 'region_id': 'bcycle_lametro_region_1', 'address': '834 N Alameda St', 'name': 'Union Station West Portal', 'station_id': 'bcycle_lametro_3014'}, {'lon': -118.24156, 'lat': 34.0529, 'region_id': 'bcycle_lametro_region_1', 'address': '201 N Los Angeles Street', 'name': 'Los Angeles & Temple', 'station_id': 'bcycle_lametro_3016'}, {'lon': -118.26014, 'lat': 34.04373, 'region_id': 'bcycle_lametro_region_1', 'address': '919 S Grand Ave', 'name': 'Grand & Olympic', 'station_id': 'bcycle_lametro_3018'}, {'lon': -118.26086, 'lat': 34.03861, 'region_id': 'bcycle_lametro_region_1', 'address': '129 W 12th Street', 'name': '12th & Hill', 'station_id': 'bcycle_lametro_3019'}, {'lon': -118.26709, 'lat': 34.03105, 'region_id': 'bcycle_lametro_region_1', 'address': '1950 S Hill Street', 'name': 'Hill & Washington', 'station_id': 'bcycle_lametro_3020'}, {'lon': -118.23309, 'lat': 34.04607, 'region_id': 'bcycle_lametro_region_1', 'address': '999 E Third Street', 'name': '3rd & Santa Fe', 'station_id': 'bcycle_lametro_3022'}, {'lon': -118.24097, 'lat': 34.05091, 'region_id': 'bcycle_lametro_region_1', 'address': '134 Judge John Aiso Street', 'name': '1st & Judge John Aiso', 'station_id': 'bcycle_lametro_3023'}, {'lon': -118.24897, 'lat': 34.05772, 'region_id': 'bcycle_lametro_region_1', 'address': '111 N Hope Street', 'name': 'Hope & 1st', 'station_id': 'bcycle_lametro_3024'}, {'lon': -118.26808, 'lat': 34.03286, 'region_id': 'bcycle_lametro_region_1', 'address': '1014 S Grand Ave', 'name': 'Grand & Washington', 'station_id': 'bcycle_lametro_3025'}, {'lon': -118.24588, 'lat': 34.06318, 'region_id': 'bcycle_lametro_region_1', 'address': '668 N Figueroa Street', 'name': 'Figueroa & Cesar Chavez', 'station_id': 'bcycle_lametro_3026'}, {'lon': -118.24716, 'lat': 34.04998, 'region_id': 'bcycle_lametro_region_1', 'address': '300 S Spring Street', 'name': 'Spring & 3rd', 'station_id': 'bcycle_lametro_3027'}, {'lon': -118.24609, 'lat': 34.05832, 'region_id': 'bcycle_lametro_region_1', 'address': '310 N Grand Ave', 'name': 'Grand & Temple', 'station_id': 'bcycle_lametro_3028'}, {'lon': -118.24642, 'lat': 34.04885, 'region_id': 'bcycle_lametro_region_1', 'address': '334 S Main Street', 'name': 'Main & 4th', 'station_id': 'bcycle_lametro_3029'}, {'lon': -118.24353, 'lat': 34.05194, 'region_id': 'bcycle_lametro_region_1', 'address': '120 S Main Street', 'name': 'Main & 1st', 'station_id': 'bcycle_lametro_3030'}, {'lon': -118.25244, 'lat': 34.0447, 'region_id': 'bcycle_lametro_region_1', 'address': '201 W 7th Street', 'name': '7th & Spring', 'station_id': 'bcycle_lametro_3031'}, {'lon': -118.25588, 'lat': 34.04989, 'region_id': 'bcycle_lametro_region_1', 'address': '557 S Hope Street', 'name': 'Hope & 6th', 'station_id': 'bc ...

# %%
filename_with_time = 'bikestations_' + time.strftime('%Y%m%d') + '_' + time.strftime('%H%M') + '.csv'
print(filename_with_time)
# Out:
# bikestations_20190327_1247.csv

# %% [markdown]
# # Write to new file in same folder as script

# %%
with open(filename_with_time, 'w', newline='') as file_to_write:
	writer = csv.writer(file_to_write)
	writer.writerow([
		'lon',
		'lat',
		'address',
		'name',
		'station_id',
	])
	
	for station in bikestation_data_list:
		print('Writing row...' + station['name'])
		writer.writerow([
			station['lon'],
			station['lat'],
			station['address'],
			station['name'],
			station['station_id'],
		])
